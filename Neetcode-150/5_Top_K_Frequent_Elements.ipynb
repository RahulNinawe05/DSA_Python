# %%
nums = [11,1,1,1,2,2,3,3,3]
k = 2

hash_table = {}

for num in nums:
#     # if num not in hash_table:
    hash_table[num] = hash_table.get(num,0)+1

# # for k , v in hash_table.items():
# #     if k >= 2:
# #         print(k)

# # result = [k for k,v in hash_table.items() if ka >= 2]f
# prinresultlt)
result = sorted(hash_table, key=lambda x: hash_table[x], reverse=True)[:k]
print(result)
# Out:
# [1, 3]

# %%
nums = [1,342,64,46,1,67,9,24,75]

min = 0

for i in range(0,len(nums)):
    for j in range(1, len(nums)-1):
        if nums[i] < nums[j] or min < nums[j]:
            min = nums[j]
min
# Out:
# 342

# %%
for i in range(0,len(nums)):
    print(nums[i])
# Out:
# 1
# 342
# 64
# 46
# 1
# 67
# 9
# 24
# 75
