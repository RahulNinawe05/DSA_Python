# %%
num = [1,2,6,64,65]

store = int(0)

n = len(num)
for i in range(0,n-1):
    if num[i] > num[i+1]:
        print("False")
        break
else:
    print("True")
# Out:
# True

# %%
num = [1, 2, 6, 64, 65]

n = len(num)

for i in range(0,n - 1):
    if num[i] > num[i + 1]:
        print("False")
        break
else:
    print("True")
# Out:
# 0
# 1
# 2
# 3
# True
