# %%
n = 346402430 # don't change a veriable
num = n
count = 0
while(num>0):
    digit = num % 10
    num = num //  10
    count += 1      # add 1 by 1 in count
print(count)
# Out:
# 9

# %%
a = 446526402
count_1 = 0
while (a > 0):
    count_1 +=1
    a = a // 10
print(count_1)
# Out:
# 9
