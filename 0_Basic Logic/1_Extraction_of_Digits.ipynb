# %%
n = 12345
while(n>0):
    digit = n % 10  # it's last digit
    print(digit)
    n =  n// 10     # it's Remove last digit
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
122//10
# Out:
# 12

# %%
1224%10
# Out:
# 4
